# %% [markdown]
# ##Simple linear Regression

# %% [markdown]
# ##Author -Yashas Samaga

# %% [markdown]
# ### libraries

# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Data Set

# %%
df = pd.read_csv("Salary_Data.csv")
print("Data")
print(df)

x= df.iloc[:,:-1].values
y=df.iloc[:,-1].values

print("Features")

print(x)

print("Dependent Variable")

print(y)
# Out:
# Data
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
# ...

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.2,random_state=1)

# %% [markdown]
# ### Training simple linear regression model on the training set

# %%
from sklearn import linear_model
regressor=linear_model.LinearRegression()
regressor.fit(X_train,y_train)
# fit methd trains the model on the training set
# Out:
# LinearRegression()

# %% [markdown]
# ###Predicting Test Set resukts

# %%
y_predict=regressor.predict(X_test)

# %%
y_predict
# Out:
# array([75074.50510972, 91873.8056381 , 62008.38247653, 81607.56642631,
#        67608.14931932, 89073.92221671])

# %%
y_test
# Out:
# array([83088., 98273., 63218., 93940., 61111., 91738.])

# %%
X_test
# Out:
# array([[5.3],
#        [7.1],
#        [3.9],
#        [6. ],
#        [4.5],
#        [6.8]])

# %% [markdown]
# ###visualizing training set results

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('salary vs Exp - Trainng Set')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ###visualizing Test set results

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_test,y_predict,color='blue')
plt.title('salary vs Exp - Test Set')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# y=mX+c
# where
#
# 1.   m - solpe or coefficient or weight
# 2.   c - intercept
# 3.   X- independent variable , years of exp
# 4.   y- dependent variable, label, salary

# %%
print("Slope:", regressor.coef_)
print("Intercept:", regressor.intercept_)
# Out:
# Slope: [9332.94473799]
# Intercept: 25609.89799835482

# %% [markdown]
# Prediction with 2 years of exp

# %%
regressor.predict( [[2]])
# Out:
# array([44275.78747434])
